# %%
# %cd /content/drive/MyDrive/KIFIYA Projects/Rossmann-Pharmaceuticals
# Out:
# /content/drive/MyDrive/KIFIYA Projects/Rossmann-Pharmaceuticals

# %%
import sys
import os

sys.path.append(os.path.abspath('/content/drive/MyDrive/KIFIYA Projects/Rossmann-Pharmaceuticals/scripts/flask_api'))

# %%
from app import app

# Start the Flask app
app.run(debug=True)
